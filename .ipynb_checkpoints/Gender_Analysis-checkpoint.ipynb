# %% [markdown]
# # The New Bechdel test!
# Analysis Character metadata in this notebook

# %%
import csv
import pandas as pd
import re
import numpy as np
import plotly.plotly as py
import plotly.graph_objs as go
from unidecode import unidecode
import pickle
from sklearn.feature_extraction import DictVectorizer
from sklearn.utils import shuffle
from sklearn.tree import DecisionTreeClassifier
from plotly import tools

# %%
mcm_df = pd.read_csv("mcm_csv.csv")

# %%
mcm_df.describe()
# Out:
#        Character_Id Character_Name Movie_Number Movie_Title Gender  \
# count          9033           9033         9033        9033   9033
# unique         9033           5355          617         617      4
# top           u1493            MAN         m289      casino      m
# freq              1             44           44          44   6014
#
#        Position_in_Credits
# count                 9033
# unique                  57
# top                      ?
# freq                  6354

# %%
mcm_df.Gender.unique()
# Out:
# array(['f', 'm', 'M', 'F'], dtype=object)

# %%
# Since, there are 4 types of same gender characters let's condense them
mcm_df['Gender'] = mcm_df['Gender'].apply(lambda x: chr(ord(x)+32) if ord(x) > 65 and ord(x) < 90 else x)

# %%
mcm_df.Gender.unique()
# Now we have only two characters
# Out:
# array(['f', 'm'], dtype=object)

# %%
mcm_df.Gender.describe()
# Out:
# count     9033
# unique       2
# top          m
# freq      6164
# Name: Gender, dtype: object

# %%
mcm_df.Gender.value_counts()
# Out:
# m    6164
# f    2869
# Name: Gender, dtype: int64

# %% [markdown]
# # Meaning,
# There are a total of : <br>
# 6164 Male Characters <br>
# 2869 Female Characters in the entire dataset. <br>
#
# So, out of 617 movies with a total character count of 9033 in all of those movies we get : <br>
# Female % = 2869 / 9033 * 100 = 31.76132% <br>
# Male % = 6164 / 9033 * 100 = 63.23868% <br>
# Altough the female % is quite grim, this doesn't represent us with a good background of for speaking about the diversity. <br>
# Let's dig deeper <br>
# # Consider the conversations metadata for Nurse Betty (m152)

# %%
# Lets, import the dataframe
mc_df = pd.read_csv("mc_csv.csv")

# %%
mc_df.describe()
# Out:
#        Character_Id1 Character_Id2 Movie_Number       List_of_Utterance
# count          83097         83097        83097                   83097
# unique          5420          5608          617                   83097
# top            u4331         u1475         m289  ['L503448', 'L503449']
# freq             193           187          338                       1

# %%
# So, the columns here in this dataset mention that characterId1 
# is the charcter speking to characterId2 in each movies
m_df = mc_df.loc[mc_df['Movie_Number'] == 'm152']

# %%
m_df.describe()
# Out:
#        Character_Id1 Character_Id2 Movie_Number       List_of_Utterance
# count            223           223          223                     223
# unique            12            17            1                     223
# top            u2369         u2389         m152  ['L423498', 'L423499']
# freq             101            60          223                       1

# %%
m_df.Character_Id1.unique()
# Out:
# array(['u2368', 'u2369', 'u2370', 'u2371', 'u2374', 'u2379', 'u2380',
#        'u2381', 'u2382', 'u2385', 'u2387', 'u2388'], dtype=object)

# %%
m_df.Character_Id2.unique()
# Out:
# array(['u2375', 'u2369', 'u2387', 'u2382', 'u2371', 'u2372', 'u2388',
#        'u2379', 'u2374', 'u2378', 'u2384', 'u2386', 'u2383', 'u2376',
#        'u2389', 'u2377', 'u2373'], dtype=object)

# %%
m1_df = mcm_df.loc[mcm_df['Movie_Number'] == 'm152']
# Which has 22 characters

# %%
print("Number of characters:", m1_df.shape[0])
m1_df.head()
# Out:
# ('Number of characters:', 22)
#      Character_Id Character_Name Movie_Number  Movie_Title Gender  \
# 2368        u2368        BALLARD         m152  nurse betty      m
# 2369        u2369          BETTY         m152  nurse betty      f
# 2370        u2370          BLAKE         m152  nurse betty      m
# 2371        u2371        CHARLIE         m152  nurse betty      m
# 2372        u2372    CHIEF NURSE         m152  nurse betty      f
#
#      Position_in_Credits
# 2368                   8
# 2369                   2
# 2370                   ?
# 2371                   1
# 2372                   ?

# %%
print("Number of conversations:", m_df.shape[0])
m_df.head()
# Out:
# ('Number of conversations:', 223)
#       Character_Id1 Character_Id2 Movie_Number  \
# 21699         u2368         u2375         m152
# 21700         u2368         u2375         m152
# 21701         u2368         u2369         m152
# 21702         u2368         u2369         m152
# 21703         u2368         u2369         m152
#
#                                        List_of_Utterance
# 21699  ['L423645', 'L423646', 'L423647', 'L423648', '...
# 21700       ['L423656', 'L423657', 'L423658', 'L423659']
# 21701       ['L423341', 'L423342', 'L423343', 'L423344']
# 21702  ['L423714', 'L423715', 'L423716', 'L423717', '...
# 21703                             ['L424468', 'L424469']

# %%
new_df = pd.DataFrame(columns = ['Character_Id1', 'Character_Id2', 'Gender1', 
                                 'Gender2', 'List_of_Utterance', 'Movie_Number',
                                 'Movie_Title', 'Name1', 'Name2'])

# %%
new_df = new_df.append(m_df, ignore_index = True)

# %%
for index, rows in new_df.iterrows():
    rows[2] = m1_df.loc[m1_df.Character_Id == rows[0], 'Gender'].iloc[0]
    rows[3] = m1_df.loc[m1_df.Character_Id == rows[1], 'Gender'].iloc[0]
    rows[6] = m1_df.loc[m1_df.Movie_Number == rows[5], 'Movie_Title'].iloc[0]
    rows[7] = m1_df.loc[m1_df.Character_Id == rows[0], 'Character_Name'].iloc[0]
    rows[8] = m1_df.loc[m1_df.Character_Id == rows[1], 'Character_Name'].iloc[0]

# %%
# Our final DF for the movie
new_df
# Out:
#     Character_Id1 Character_Id2 Gender1 Gender2  \
# 0           u2368         u2375       m       m
# 1           u2368         u2375       m       m
# 2           u2368         u2369       m       f
# 3           u2368         u2369       m       f
# 4           u2368         u2369       m       f
# 5           u2368         u2387       m       m
# 6           u2368         u2387       m       m
# 7           u2368         u2387       m       m
# 8           u2368         u2387       m       m
# 9           u2368         u2387       m       m
# 10          u2368         u2387       m       m
# 11          u2368         u2387       m       m
# 12          u2368         u2387       m       m
# 13          u2368         u2387       m       m
# 14          u2368         u2387       m       m
# 15          u2368         u2387       m       m
# 16          u2368         u2387       m       m
# 17          u2368         u2387       m       m
# 18          u2368         u2387       m       m
# 19          u2368         u2387       m       m
# 20          u2368         u2387       m       m
# 21          u2368         u2387       m       m
# 22          u2368         u2387       m       m
# 23          u2368         u2387       m       m
# 24          u2368         u2387       m       m
# 25          u2368         u2387       m       m
# 26          u2368         u2387       m       m
# 27          u2369         u2382       f       f
# 28          u2369         u2382       f       f
# 29          u2369         u2371       f       m
# ..            ...           ...     ...     ...
# 193         u2374         u2389       m       m
# 194         u2374         u2389       m       m
# 195         u2374         u2389       m       m
# 196         u2374         u2389       m       m
# 197         u2379         u2384       m       f
# 198         u2379         u2384       m       f
# 199         u2379         u2384       m       f
# 200         u2379         u2384       m       f
# 201         u2379         u2384       m       f
# 202         u2379         u2384       m       f
# 203         u2379         u2384       m       f
# 204         u2379         u2384       m       f
# 205         u2379         u2384       m       f
# 206         u2379         u2384       m       f
# 207         u2380         u2389       m       m
# 208         u2380         u2389       m       m
# 209         u2381         u2389       m       m
# 210         u2381         u2389       m       m
# 211         u2382         u2387       f       m
# 212         u2382         u2387       f       m
# 213         u2382         u2387       f       m
# 214         u2382         u2387       f       m
# 215         u2385         u2386       f       f
# 216         u2385         u2386       f       f
# 217         u2387         u2389       m       m
# 218         u2387         u2389       m       m
# 219         u2388         u2389       f       m
# 220         u2388         u2389       f       m
# 221         u2388         u2389       f       m
# 222         u2388         u2389       f       m
#
#                                      List_of_Utterance Movie_Number  \
# 0    ['L423645', 'L423646', 'L423647', 'L423648', '...         m152
# 1         ['L423656', 'L423657', 'L423658', 'L423659']         m152
# 2         ['L423341', 'L423342', 'L423343', 'L423344']         m152
# 3    ['L423714', 'L423715', 'L423716', 'L423717', '...         m152
# 4                               ['L424468', 'L424469']         m152
# 5                    ['L423338', 'L423339', 'L423340']         m152
# 6         ['L423345', 'L423346', 'L423347', 'L423348']         m152
# 7    ['L423350', 'L423351', 'L423352', 'L423353', '...         m152
# 8    ['L423592', 'L423593', 'L423594', 'L423595', '...         m152
# 9                               ['L423605', 'L423606']         m152
# 10   ['L423608', 'L423609', 'L423610', 'L423611', '...         m152
# 11   ['L423634', 'L423635', 'L423636', 'L423637', '...         m152
# 12                              ['L423650', 'L423651']         m152
# 13        ['L423652', 'L423653', 'L423654', 'L423655']         m152
# 14   ['L423723', 'L423724', 'L423725', 'L423726', '...         m152
# 15                   ['L423853', 'L423854', 'L423855']         m152
# 16                   ['L423858', 'L423859', 'L423860']         m152
# 17                              ['L423862', 'L423863']         m152
# 18                              ['L423866', 'L423867']         m152
# 19        ['L424086', 'L424087', 'L424088', 'L424089']         m152
# 20                              ['L424090', 'L424091']         m152
# 21                   ['L424240', 'L424241', 'L424242']         m152
# 22   ['L424243', 'L424244', 'L424245', 'L424246', '...         m152
# 23                   ['L424502', 'L424503', 'L424504']         m152
# 24                              ['L424537', 'L424538']         m152
# 25                   ['L424547', 'L424548', 'L424549']         m152
# 26                   ['L424552', 'L424553', 'L424554']         m152
# 27                   ['L423399', 'L423400', 'L423401']         m152
# 28   ['L423403', 'L423404', 'L423405', 'L423406', '...         m152
# 29                   ['L424475', 'L424476', 'L424477']         m152
# ..                                                 ...          ...
# 193                             ['L423492', 'L423493']         m152
# 194                             ['L423498', 'L423499']         m152
# 198  nurse betty    GEORGE     LYLA
# 199  nurse betty    GEORGE     LYLA
# 200  nurse betty    GEORGE     LYLA
# 201  nurse betty    GEORGE     LYLA
# 202  nurse betty    GEORGE     LYLA
# 203  nurse betty    GEORGE     LYLA
# 204  nurse betty    GEORGE     LYLA
# 205  nurse betty    GEORGE     LYLA
# 206  nurse betty    GEORGE     LYLA
# 207  nurse betty     GUARD   WESLEY
# 208  nurse betty     GUARD   WESLEY
# 209  nurse betty   JERROLD   WESLEY
# 210  nurse betty   JERROLD   WESLEY
# 211  nurse betty     JOYCE      ROY
# 212  nurse betty     JOYCE      ROY
# 213  nurse betty     JOYCE      ROY
# 214  nurse betty     JOYCE      ROY
# 215  nurse betty  MERCEDES     ROSA
# 216  nurse betty  MERCEDES     ROSA
# 217  nurse betty       ROY   WESLEY
# 218  nurse betty       ROY   WESLEY
# 219  nurse betty   SUE ANN   WESLEY
# 220  nurse betty   SUE ANN   WESLEY
# 221  nurse betty   SUE ANN   WESLEY
# 222  nurse betty   SUE ANN   WESLEY
#
# [223 rows x 9 columns]

# %%
new_df.describe()
# Out:
#        Character_Id1 Character_Id2 Gender1 Gender2       List_of_Utterance  \
# count            223           223     223     223                     223
# unique            12            17       2       2                     223
# top            u2369         u2389       m       m  ['L423498', 'L423499']
# freq             101            60     112     150                       1
#
#        Movie_Number  Movie_Title  Name1   Name2
# count           223          223    223     223
# unique            1            1     12      17
# top            m152  nurse betty  BETTY  WESLEY
# freq            223          223    101      60

# %%
# Let's look deeper into the data for this movie
print(new_df.Gender1.value_counts())
print(new_df.Gender2.value_counts())
# Out:
# m    112
# f    111
# Name: Gender1, dtype: int64
# m    150
# f     73
# Name: Gender2, dtype: int64

# %%
# Visualization on the year of realese to get the idea of movie years we are working with
data = [go.Histogram(
            x=new_df['Name1'],
            marker = dict(color = 'rgb(17, 157, 100)'),
            hoverlabel = dict(bordercolor = 'rgb(0, 0, 0)')
        )]
layout = go.Layout(
    title = 'Name1 list of utterance',
    xaxis=dict(
        title='Character Names'
    ),
    yaxis=dict(
        title='Counts of Utterances'
    ),
    bargap=0.2
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/1.embed" height="525px" width="100%"></iframe>

# %%
# Visualization on the year of realese to get the idea of movie years we are working with
data = [go.Histogram(
            x=new_df['Name2'],
            marker = dict(color = 'rgb(255, 0, 127)'),
            hoverlabel = dict(bordercolor = 'rgb(1, 1, 1)')
        )]
layout = go.Layout(
    title = 'Name2 list of utternaces',
    xaxis=dict(
        title='Name2'
    ),
    yaxis=dict(
        title='Counts of Utterances'
    ),
    bargap=0.2
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/1.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Graph visualization using Pydot and Graphviz

# %%
import pydot
import graphviz
from IPython.display import Image, display

# %%
G = pydot.Dot(graph_type="digraph")

# %%
# Add nodes as all the characters in the movie Nurse Betty
for index, rows in m1_df.iterrows():
    node = pydot.Node(rows[1], style="filled", fillcolor="yellow")
    G.add_node(node)

# %%
# Add edges between these nodes based on the other dataframe
for index, rows in new_df.iterrows():
    edge = pydot.Edge(rows[7], rows[8])
    G.add_edge(edge)

# %%
im = Image(G.create_png(), width="5000px", height="5000px")
display(im)

# %%
# Trying to do something like this using Plotly
edge_trace = go.Scatter(
    x=[],
    line=dict(width=1.0,color='#888'))

# %%
for index, rows in new_df.iterrows():
    edge_trace['x'] += tuple([rows[7], rows[8], None])

# %%
fig = go.Figure(data=[edge_trace],
             layout=go.Layout(
                 title='<br>Network graph made with Python',
                 xaxis=dict(
                     title="Characters"
                 ),
                 yaxis=dict(
                     title="Dialogue numbers"
                 )
                ))

py.iplot(fig, filename='networkx')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/5.embed" height="525px" width="100%"></iframe>

# %% [markdown]
# # Consider the conversations metadata for Indiana Jones and the temple of doom (m99)

# %%
# So, the columns here in this dataset mention that characterId1 
# is the charcter speking to characterId2 in each movies
m99_df = mc_df.loc[mc_df['Movie_Number'] == 'm99']

# %%
m99_df.describe()
# Out:
#        Character_Id1 Character_Id2 Movie_Number  \
# count            138           138          138
# unique             4             7            1
# top            u1463         u1468          m99
# freq             103            84          138
#
#                                         List_of_Utterance
# count                                                 138
# unique                                                138
# top     ['L300221', 'L300222', 'L300223', 'L300224', '...
# freq                                                    1

# %%
m99_df.Character_Id1.unique()
# Out:
# array(['u1461', 'u1462', 'u1463', 'u1467'], dtype=object)

# %%
m99_df.Character_Id2.unique()
# Out:
# array(['u1462', 'u1463', 'u1468', 'u1464', 'u1467', 'u1465', 'u1466'],
#       dtype=object)

# %%
m991_df = mcm_df.loc[mcm_df['Movie_Number'] == 'm99']
# Which has 22 characters

# %%
print("Number of characters:", m991_df.shape[0])
m991_df.head()
# Out:
# ('Number of characters:', 8)
#      Character_Id   Character_Name Movie_Number  \
# 1461        u1461  CAPT. BLUMBURTT          m99
# 1462        u1462      CHATTAR LAL          m99
# 1463        u1463          INDIANA          m99
# 1464        u1464              LAO          m99
# 1465        u1465         MOLA RAM          m99
#
#                                Movie_Title Gender Position_in_Credits
# 1461  indiana jones and the temple of doom      m                   ?
# 1462  indiana jones and the temple of doom      f                   ?
# 1463  indiana jones and the temple of doom      m                   1
# 1464  indiana jones and the temple of doom      m                   ?
# 1465  indiana jones and the temple of doom      f                   ?

# %%
print("Number of conversations:", m99_df.shape[0])
m99_df.head()
# Out:
# ('Number of conversations:', 138)
#       Character_Id1 Character_Id2 Movie_Number  \
# 13514         u1461         u1462          m99
# 13515         u1461         u1462          m99
# 13516         u1461         u1462          m99
# 13517         u1461         u1463          m99
# 13518         u1461         u1463          m99
#
#                                        List_of_Utterance
# 13514                  ['L300310', 'L300311', 'L300312']
# 13515                             ['L300342', 'L300343']
# 13516                  ['L300570', 'L300571', 'L300572']
# 13517                             ['L300316', 'L300317']
# 13518  ['L300318', 'L300319', 'L300320', 'L300321', '...

# %%
new2_df = pd.DataFrame(columns = ['Character_Id1', 'Character_Id2', 'Gender1', 
                                 'Gender2', 'List_of_Utterance', 'Movie_Number',
                                 'Movie_Title', 'Name1', 'Name2'])

# %%
new2_df = new2_df.append(m99_df, ignore_index = True)

# %%
for index, rows in new2_df.iterrows():
    rows[2] = m991_df.loc[m991_df.Character_Id == rows[0], 'Gender'].iloc[0]
    rows[3] = m991_df.loc[m991_df.Character_Id == rows[1], 'Gender'].iloc[0]
    rows[6] = m991_df.loc[m991_df.Movie_Number == rows[5], 'Movie_Title'].iloc[0]
    rows[7] = m991_df.loc[m991_df.Character_Id == rows[0], 'Character_Name'].iloc[0]
    rows[8] = m991_df.loc[m991_df.Character_Id == rows[1], 'Character_Name'].iloc[0]

# %%
# Our final DF for the movie
new2_df
# Out:
#     Character_Id1 Character_Id2 Gender1 Gender2  \
# 0           u1461         u1462       m       f
# 1           u1461         u1462       m       f
# 2           u1461         u1462       m       f
# 3           u1461         u1463       m       m
# 4           u1461         u1463       m       m
# 5           u1461         u1463       m       m
# 6           u1461         u1463       m       m
# 7           u1461         u1463       m       m
# 8           u1461         u1463       m       m
# 9           u1461         u1463       m       m
# 10          u1461         u1463       m       m
# 11          u1461         u1468       m       f
# 12          u1461         u1468       m       f
# 13          u1461         u1468       m       f
# 14          u1462         u1468       f       f
# 15          u1462         u1468       f       f
# 16          u1462         u1468       f       f
# 17          u1462         u1468       f       f
# 18          u1462         u1468       f       f
# 19          u1462         u1468       f       f
# 20          u1462         u1468       f       f
# 21          u1462         u1463       f       m
# 22          u1462         u1463       f       m
# 23          u1462         u1463       f       m
# 24          u1462         u1463       f       m
# 25          u1462         u1463       f       m
# 26          u1462         u1463       f       m
# 27          u1462         u1463       f       m
# 28          u1462         u1463       f       m
# 29          u1462         u1463       f       m
# ..            ...           ...     ...     ...
# 108         u1463         u1468       m       f
# 109         u1463         u1468       m       f
# 110         u1463         u1468       m       f
# 111         u1463         u1468       m       f
# 112         u1463         u1468       m       f
# 113         u1463         u1468       m       f
# 114         u1463         u1468       m       f
# 115         u1463         u1468       m       f
# 116         u1463         u1468       m       f
# 117         u1463         u1468       m       f
# 118         u1463         u1468       m       f
# 119         u1463         u1468       m       f
# 120         u1463         u1468       m       f
# 121         u1463         u1468       m       f
# 122         u1463         u1468       m       f
# 123         u1463         u1468       m       f
# 124         u1463         u1468       m       f
# 125         u1463         u1468       m       f
# 126         u1463         u1468       m       f
# 127         u1463         u1468       m       f
# 128         u1463         u1468       m       f
# 129         u1463         u1468       m       f
# 130         u1463         u1468       m       f
# 131         u1463         u1468       m       f
# 132         u1463         u1468       m       f
# 133         u1463         u1468       m       f
# 134         u1467         u1468       m       f
# 135         u1467         u1468       m       f
# 136         u1467         u1468       m       f
# 137         u1467         u1468       m       f
#
#                                      List_of_Utterance Movie_Number  \
# 0                    ['L300310', 'L300311', 'L300312']          m99
# 1                               ['L300342', 'L300343']          m99
# 2                    ['L300570', 'L300571', 'L300572']          m99
# 3                               ['L300316', 'L300317']          m99
# 4    ['L300318', 'L300319', 'L300320', 'L300321', '...          m99
# 5                               ['L300323', 'L300324']          m99
# 6                               ['L300325', 'L300326']          m99
# 7                               ['L300359', 'L300360']          m99
# 8                               ['L300379', 'L300380']          m99
# 9                    ['L300563', 'L300564', 'L300565']          m99
# 10                              ['L300567', 'L300568']          m99
# 11                              ['L300328', 'L300329']          m99
# 12        ['L300544', 'L300545', 'L300546', 'L300547']          m99
# 13                              ['L300550', 'L300551']          m99
# 14                              ['L300290', 'L300291']          m99
# 15                              ['L300294', 'L300295']          m99
# 16                   ['L300299', 'L300300', 'L300301']          m99
# 17                              ['L300302', 'L300303']          m99
# 18                   ['L300313', 'L300314', 'L300315']          m99
# 19                              ['L300548', 'L300549']          m99
# 20                              ['L300552', 'L300553']          m99
# 21                   ['L300287', 'L300288', 'L300289']          m99
# 22                              ['L300296', 'L300297']          m99
# 23                   ['L300339', 'L300340', 'L300341']          m99
# 24                   ['L300346', 'L300347', 'L300348']          m99
# 25                              ['L300349', 'L300350']          m99
# 26                   ['L300356', 'L300357', 'L300358']          m99
# 27                   ['L300361', 'L300362', 'L300363']          m99
# 28   ['L300367', 'L300368', 'L300369', 'L300370', '...          m99
# 29                              ['L300587', 'L300588']          m99
# ..                                                 ...          ...
# 108                  ['L300413', 'L300414', 'L300415']          m99
# 109                             ['L300416', 'L300417']          m99
# 110                             ['L300429', 'L300430']          m99
# 111                             ['L300431', 'L300432']          m99
# 112                  ['L300434', 'L300435', 'L300436']          m99
# 113                             ['L300459', 'L300460']          m99
# 114                             ['L300464', 'L300465']          m99
# 115                             ['L300469', 'L300470']          m99
# 116                             ['L300472', 'L300473']          m99
# 117                             ['L300474', 'L300475']          m99
# 118                  ['L300477', 'L300478', 'L300479']          m99
# 119                             ['L300483', 'L300484']          m99
# 120                             ['L300489', 'L300490']          m99
# 121                             ['L300491', 'L300492']          m99
# 122                             ['L300495', 'L300496']          m99
# 123  ['L300502', 'L300503', 'L300504', 'L300505', '...          m99
# 124                             ['L300556', 'L300557']          m99
# 125       ['L300559', 'L300560', 'L300561', 'L300562']          m99
# 126       ['L300574', 'L300575', 'L300576', 'L300577']          m99
# 127                  ['L300579', 'L300580', 'L300581']          m99
# 128                             ['L300615', 'L300616']          m99
# 129                             ['L300620', 'L300621']          m99
# 130                             ['L300652', 'L300653']          m99
# 131                             ['L300658', 'L300659']          m99
# 132                             ['L300690', 'L300691']          m99
# 133  ['L300698', 'L300699', 'L300700', 'L300701', '...          m99
# 134                             ['L300114', 'L300115']          m99
# 135       ['L300187', 'L300188', 'L300189', 'L300190']          m99
# 136                  ['L300353', 'L300354', 'L300355']          m99
# 137                             ['L300641', 'L300642']          m99
#
#                               Movie_Title            Name1        Name2
# 0    indiana jones and the temple of doom  CAPT. BLUMBURTT  CHATTAR LAL
# 1    indiana jones and the temple of doom  CAPT. BLUMBURTT  CHATTAR LAL
# 2    indiana jones and the temple of doom  CAPT. BLUMBURTT  CHATTAR LAL
# 134  indiana jones and the temple of doom      SHORT ROUND       WILLIE
# 135  indiana jones and the temple of doom      SHORT ROUND       WILLIE
# 136  indiana jones and the temple of doom      SHORT ROUND       WILLIE
# 137  indiana jones and the temple of doom      SHORT ROUND       WILLIE
#
# [138 rows x 9 columns]

# %%
new2_df.describe()
# Out:
#        Character_Id1 Character_Id2 Gender1 Gender2  \
# count            138           138     138     138
# unique             4             7       2       2
# top            u1463         u1468       m       f
# freq             103            84     121      92
#
#                                         List_of_Utterance Movie_Number  \
# count                                                 138          138
# unique                                                138            1
# top     ['L300221', 'L300222', 'L300223', 'L300224', '...          m99
# freq                                                    1          138
#
#                                  Movie_Title    Name1   Name2
# count                                    138      138     138
# unique                                     1        4       7
# top     indiana jones and the temple of doom  INDIANA  WILLIE
# freq                                     138      103      84

# %%
# Let's look deeper into the data for this movie
print(new2_df.Gender1.value_counts())
print(new2_df.Gender2.value_counts())
# Out:
# m    121
# f     17
# Name: Gender1, dtype: int64
# f    92
# m    46
# Name: Gender2, dtype: int64

# %%
# Visualization on the year of realese to get the idea of movie years we are working with
data = [go.Histogram(
            x=new2_df['Name1'],
            marker = dict(color = 'rgb(17, 157, 100)'),
            hoverlabel = dict(bordercolor = 'rgb(0, 0, 0)')
        )]
layout = go.Layout(
    title = 'Name2 list of utterance',
    xaxis=dict(
        title='Character Names'
    ),
    yaxis=dict(
        title='Counts of Utterances'
    ),
    bargap=0.2
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/1.embed" height="525px" width="100%"></iframe>

# %%
# Visualization on the year of realese to get the idea of movie years we are working with
data = [go.Histogram(
            x=new2_df['Name2'],
            marker = dict(color = 'rgb(17, 157, 100)'),
            hoverlabel = dict(bordercolor = 'rgb(0, 0, 0)')
        )]
layout = go.Layout(
    title = 'Name1 list of utterance',
    xaxis=dict(
        title='Character Names'
    ),
    yaxis=dict(
        title='Counts of Utterances'
    ),
    bargap=0.2
)
fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='simple-histogram')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/1.embed" height="525px" width="100%"></iframe>

# %%
G2 = pydot.Dot(graph_type="digraph")

# %%
# Add nodes as all the characters in the movie Nurse Betty
for index, rows in m991_df.iterrows():
    node = pydot.Node(rows[1], style="filled", fillcolor="yellow")
    G2.add_node(node)

# %%
# Add edges between these nodes based on the other dataframe
for index, rows in new2_df.iterrows():
    edge = pydot.Edge(rows[7], rows[8])
    G2.add_edge(edge)

# %%
im = Image(G2.create_png(), width="5000px", height="5000px")
display(im)

# %%
# Trying to do something like this using Plotly
edge_trace = go.Scatter(
    x=[],
    line=dict(width=1.0,color='#888'))

# %%
for index, rows in new2_df.iterrows():
    edge_trace['x'] += tuple([rows[7], rows[8], None])

# %%
fig = go.Figure(data=[edge_trace],
             layout=go.Layout(
                 title='<br>Network graph made with Python',
                 xaxis=dict(
                     title="Characters"
                 ),
                 yaxis=dict(
                     title="Dialogue numbers"
                 )
                ))

py.iplot(fig, filename='networkx')
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~canfindck/5.embed" height="525px" width="100%"></iframe>
