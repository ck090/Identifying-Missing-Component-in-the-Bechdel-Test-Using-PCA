# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("New_Bechdel_Class_Labels.csv")

# %%
df.drop(["Female_Male_Dialogues_Ratio"], inplace = True, axis = 1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 324 entries, 0 to 323
# Data columns (total 25 columns):
# Year                      324 non-null object
# Movie_Title               324 non-null object
# New ROI                   324 non-null object
# Genre1_Tag_Female         324 non-null float64
# Genre1_Tag_Male           324 non-null float64
# Genre2_Tag_Female         324 non-null float64
# Genre2_Tag_Male           324 non-null float64
# Genre3_Tag_Female         324 non-null float64
# Genre3_Tag_Male           324 non-null float64
# IMDB_Rating               324 non-null float64
# #_of_Female_Cast          324 non-null int64
# #_of_Male_Cast            324 non-null int64
# #_of_Female_Dialogue      324 non-null int64
# #_of_Male_Dialogue        324 non-null int64
# #_of_Female_Crew          324 non-null int64
# #_of_Male_Crew            324 non-null int64
# Sentiment_Female          324 non-null float64
# Sentiment_Male            324 non-null float64
# ...

# %%
zero_df = df.loc[df['labels'] == 0]
first_df = df.loc[df['labels'] == 1]
second_df = df.loc[df['labels'] == 2]
third_df = df.loc[df['labels'] == 3]

# %%
first_df.describe()
# Out:
#        Genre1_Tag_Female  Genre1_Tag_Male  Genre2_Tag_Female  Genre2_Tag_Male  \
# count          47.000000        47.000000          47.000000        47.000000
# mean            0.111678         0.114691           0.103790         0.105709
# std             0.019406         0.021026           0.045562         0.046638
# min             0.067212         0.065007           0.000000         0.000000
# 25%             0.099329         0.099931           0.096238         0.095035
# 50%             0.111169         0.114050           0.119230         0.119392
# 75%             0.123220         0.128143           0.132006         0.135331
# max             0.159606         0.167139           0.168472         0.169060
#
#        Genre3_Tag_Female  Genre3_Tag_Male  IMDB_Rating  #_of_Female_Cast  \
# count          47.000000        47.000000    47.000000         47.000000
# mean            0.069448         0.070992     6.914894          6.808511
# ...

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['Genre1_Tag_Female'], norm_hist = True, rug = True, label = 'Zero')
sns.distplot(first_df['Genre1_Tag_Female'], norm_hist = True, rug = True, label = 'First')
sns.distplot(second_df['Genre1_Tag_Female'], norm_hist = True, rug = True, label = 'Second')
sns.distplot(third_df['Genre1_Tag_Female'], norm_hist = True, rug = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['Genre2_Tag_Female'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['Genre2_Tag_Female'], norm_hist = True, label = 'First')
sns.distplot(second_df['Genre2_Tag_Female'], norm_hist = True, label = 'Second')
sns.distplot(third_df['Genre2_Tag_Female'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['noun_count_female'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['noun_count_female'], norm_hist = True, label = 'First')
sns.distplot(second_df['noun_count_female'], norm_hist = True, label = 'Second')
sns.distplot(third_df['noun_count_female'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['verb_count_female'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['verb_count_female'], norm_hist = True, label = 'First')
sns.distplot(second_df['verb_count_female'], norm_hist = True, label = 'Second')
sns.distplot(third_df['verb_count_female'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['adjective_count_female'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['adjective_count_female'], norm_hist = True, label = 'First')
sns.distplot(second_df['adjective_count_female'], norm_hist = True, label = 'Second')
sns.distplot(third_df['adjective_count_female'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['#_of_Female_Dialogue'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['#_of_Female_Dialogue'], norm_hist = True, label = 'First')
sns.distplot(second_df['#_of_Female_Dialogue'], norm_hist = True, label = 'Second')
sns.distplot(third_df['#_of_Female_Dialogue'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['#_of_Male_Dialogue'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['#_of_Male_Dialogue'], norm_hist = True, label = 'First')
sns.distplot(second_df['#_of_Male_Dialogue'], norm_hist = True, label = 'Second')
sns.distplot(third_df['#_of_Male_Dialogue'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['#_of_Female_Crew'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['#_of_Female_Crew'], norm_hist = True, label = 'First')
sns.distplot(second_df['#_of_Female_Crew'], norm_hist = True, label = 'Second')
sns.distplot(third_df['#_of_Female_Crew'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['Sentiment_Female'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['Sentiment_Female'], norm_hist = True, label = 'First')
sns.distplot(second_df['Sentiment_Female'], norm_hist = True, label = 'Second')
sns.distplot(third_df['Sentiment_Female'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
plt.figure(figsize = [15.0, 5.0])
# fig, ax = plt.subplots(1, 4, figsize = (15, 5))
sns.distplot(zero_df['Sentiment_Male'], norm_hist = True, label = 'Zero')
sns.distplot(first_df['Sentiment_Male'], norm_hist = True, label = 'First')
sns.distplot(second_df['Sentiment_Male'], norm_hist = True, label = 'Second')
sns.distplot(third_df['Sentiment_Male'], norm_hist = True, label = 'Three')
plt.legend()
plt.show()

# %%
cor = df.corr()
plt.figure(figsize = [15.0, 10.0])
sns.heatmap(cor, linewidths = 0.1)
plt.show()

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split

# %%
y = df["labels"]

# %%
df.drop(["Movie_Title", "Year", "New ROI", "labels"], inplace = True, axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(df, y, test_size=0.33, random_state=42)

# %%
clf = svm.SVC(kernel='linear', C = 1).fit(X_train, y_train)

# %%
clf.support_ # Indices of Support vectors
# Out:
# array([  3,  21,  71,  93, 145,  20, 120, 141, 178, 208,  24, 134, 172,
#        194, 206,  70,  79,  85,  86], dtype=int32)

# %%
clf.n_support_ # Number of support vectors for each class
# Out:
# array([5, 5, 5, 4], dtype=int32)

# %%
clf.predict(df[123:130])
# Out:
# array([2, 1, 1, 3, 1, 0, 2])

# %%
y[123:130]
# Out:
# 123    2
# 124    1
# 125    1
# 126    3
# 127    1
# 128    0
# 129    2
# Name: labels, dtype: int64

# %%
clf.score(X_train, y_train)
# Out:
# 1.0

# %%
clf.score(X_test, y_test)
# Out:
# 1.0
